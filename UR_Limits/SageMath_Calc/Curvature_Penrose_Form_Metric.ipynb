# %% [markdown]
# Script to compute curvature components of the Penrose form of the metric (also called "adapted coordinate" form of the metric)

# %%
# %display None

# %%
M = Manifold(4, 'M', structure='Lorentzian')
X.<U, V, x, y> = M.chart()
X
# Out:
# Chart (M, (U, V, x, y))

# %%
a = X.function(function('a')(U, V, x, y))
bx = X.function(function('b_x')(U, V, x, y))
by = X.function(function('b_y')(U, V, x, y))
cx = X.function(function('c_x')(U, V, x, y))
cy = X.function(function('c_y')(U, V, x, y))
d = X.function(function('d')(U, V, x, y))
a, bx, by, cx, cy, d
# Out:
# (a(U, V, x, y),
#  b_x(U, V, x, y),
#  b_y(U, V, x, y),
#  c_x(U, V, x, y),
#  c_y(U, V, x, y),
#  d(U, V, x, y))

# %%
g = M.metric('g', signature=(2,0,2))
g
# Out:
# Lorentzian metric g on the 4-dimensional Lorentzian manifold M

# %%
g[0, 1], g[1, 0] = -1, -1
g[0, 2], g[2, 0], g[0, 3], g[3, 0] = 0, 0, 0, 0
g[1, 2], g[2, 1], g[1, 3], g[3, 1] = bx/2, bx/2, by/2, by/2
g[2, 2], g[3, 3] = cx, cy
g[2, 3], g[3, 2] = d/2, d/2
g[:]
# Out:
# [                  0                  -1                   0                   0]
# [                 -1                   0 1/2*b_x(U, V, x, y) 1/2*b_y(U, V, x, y)]
# [                  0 1/2*b_x(U, V, x, y)     c_x(U, V, x, y)   1/2*d(U, V, x, y)]
# [                  0 1/2*b_y(U, V, x, y)   1/2*d(U, V, x, y)     c_y(U, V, x, y)]

# %%
type(g)
# Out:
# <class 'sage.manifolds.differentiable.metric.PseudoRiemannianMetricParal'>

# %%
g.riemann()[0, 1, 2, 3]
# Out:
# 1/16*((8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*d(b_x)/dU*d(b_x)/dy + 2*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d(b_x)/dU*d(b_y)/dy + 2*(8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*d(b_y)/dU*d(c_x)/dV + 4*(4*b_y(U, V, x, y)^2*c_x(U, V, x, y)^2*c_y(U, V, x, y) + 4*b_x(U, V, x, y)^2*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_x(U, V, x, y)*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) + b_x(U, V, x, y)*b_y(U, V, x, y)*d(U, V, x, y)^3 - (b_y(U, V, x, y)^2*c_x(U, V, x, y) + b_x(U, V, x, y)^2*c_y(U, V, x, y))*d(U, V, x, y)^2)*d^2(b_x)/dUdy + 4*(8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*d^2(b_x)/dxdy + 4*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(b_x)/dy^2 - (2*(8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*d(b_x)/dx + (8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d(b_x)/dy)*d(b_y)/dU - 4*(4*b_y(U, V, x, y)^2*c_x(U, V, x, y)^2*c_y(U, V, x, y) + 4*b_x(U, V, x, y)^2*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_x(U, V, x, y)*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) + b_x(U, V, x, y)*b_y(U, V, x, y)*d(U, V, x, y)^3 - (b_y(U, V, x, y)^2*c_x(U, V, x, y) + b_x(U, V, x, y)^2*c_y(U, V, x, y))*d(U, V, x, y)^2)*d^2(b_y)/dUdx + ((8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*d(b_x)/dU - (8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d(b_y)/dU)*d(b_y)/dx - 4*(8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*d^2(b_y)/dx^2 - 4*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(b_y)/dxdy - 2*((4*b_y(U, V, x, y)^2*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)^2*d(U, V, x, y)^2)*d(b_x)/dy - (4*b_y(U, V, x, y)^2*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)^2*d(U, V, x, y)^2)*d(b_y)/dx)*d(c_x)/dU - 8*(8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*d^2(c_x)/dVdy - 2*(4*(2*b_x(U, V, x, y)*c_y(U, V, x, y)^2 - b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(b_x)/dy - (4*b_x(U, V, x, y)^2*c_y(U, V, x, y)^2 - 4*b_x(U, V, x, y)*b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) + b_y(U, V, x, y)^2*d(U, V, x, y)^2)*d(b_y)/dU - 4*(2*b_x(U, V, x, y)*c_y(U, V, x, y)^2 - b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(b_y)/dx)*d(c_x)/dx  ...

# %%
g.riemann().display_comp()
# Out:
# Riem(g)^U_UUV = 1/8*(2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - c_y(U, V, x, y)*d(U, V, x, y)^2)*(d(b_x)/dU)^2 - 2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dU*d(b_y)/dU + 2*(4*c_x(U, V, x, y)^2*c_y(U, V, x, y) - c_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU^2 + 2*(8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*d^2(b_x)/dU^2 + 2*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(b_y)/dU^2 - 2*(2*(2*b_x(U, V, x, y)*c_y(U, V, x, y)^2 - b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(b_x)/dU - (2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU)*d(c_x)/dU + 2*((2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - 2*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(b_y)/dU)*d(c_y)/dU - ((4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) + b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU + (4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) + b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU)*d(d)/dU)/(16*c_x(U, V, x, y)^2*c_y(U, V, x, y)^2 - 8*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + d(U, V, x, y)^4)
# Riem(g)^U_UUx = -1/8*(8*(2*b_x(U, V, x, y)*c_y(U, V, x, y)^2 - b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*(d(c_x)/dU)^2 - 4*(2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dU*d(c_y)/dU + (4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) + b_x(U, V, x, y)*d(U, V, x, y)^2)*(d(d)/dU)^2 + 2*(16*c_x(U, V, x, y)^2*c_y(U, V, x, y)^2 - 8*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + d(U, V, x, y)^4)*d^2(b_x)/dU^2 - 2*(2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - c_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - (4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_y)/dU)*d(c_x)/dU - 4*(8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*d^2(c_x)/dU^2 + ((4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dU - 2*(4*c_x(U, V, x, y)^2*c_y(U, V, x, y) - c_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU + 4*(2*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 3*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) + b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dU + 4*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(c_y)/dU)*d(d)/dU - 2*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(d)/dU^2)/(16*c_x(U, V, x, y)^2*c_y(U, V, x, y)^2 - 8*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + d(U, V, x, y)^4)
# Riem(g)^U_UUy = -1/8*(8*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*(d(c_y)/dU)^2 + (4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) + b_y(U, V, x, y)*d(U, V, x, y)^2)*(d(d)/dU)^2 + 2*(16*c_x(U, V, x, y)^2*c_y(U, V, x, y)^2 - 8*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + d(U, V, x, y)^4)*d^2(b_y)/dU^2 + 2*((4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dU - 2*(4*c_x(U, V, x, y)^2*c_y(U, V, x, y) - c_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU - 2*(2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dU)*d(c_y)/dU - 4*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(c_y)/dU^2 - (2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - c_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - (4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_y)/dU - 4*(2*b_x(U, V, x, y)*c_y(U, V, x, y)^2 - b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(c_x)/dU - 4*(2*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 3*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) + b_x(U, V, x, y)*d(U, V, x, y)^2)*d(c_y)/dU)*d(d)/dU - 2*(8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*d^2(d)/dU^2)/(16*c_x(U, V, x, y)^2*c_y(U, V, x, y)^2 - 8*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + d(U, V, x, y)^4)
# Riem(g)^U_UVU = -1/8*(2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - c_y(U, V, x, y)*d(U, V, x, y)^2)*(d(b_x)/dU)^2 - 2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dU*d(b_y)/dU + 2*(4*c_x(U, V, x, y)^2*c_y(U, V, x, y) - c_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU^2 + 2*(8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*d^2(b_x)/dU^2 + 2*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(b_y)/dU^2 - 2*(2*(2*b_x(U, V, x, y)*c_y(U, V, x, y)^2 - b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(b_x)/dU - (2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU)*d(c_x)/dU + 2*((2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - 2*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(b_y)/dU)*d(c_y)/dU - ((4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) + b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU + (4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) + b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU)*d(d)/dU)/(16*c_x(U, V, x, y)^2*c_y(U, V, x, y)^2 - 8*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + d(U, V, x, y)^4)
# Riem(g)^U_UVx = -1/8*((4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dU*d(b_x)/dy - 2*(4*c_x(U, V, x, y)^2*c_y(U, V, x, y) - c_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dy*d(b_y)/dU - 4*(2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dU*d(c_y)/dV + 2*(16*c_x(U, V, x, y)^2*c_y(U, V, x, y)^2 - 8*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + d(U, V, x, y)^4)*d^2(b_x)/dUdV + 2*(8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*d^2(b_x)/dUdx + 2*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(b_y)/dUdx - ((4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dU - 2*(4*c_x(U, V, x, y)^2*c_y(U, V, x, y) - c_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU)*d(b_y)/dx - 2*(4*(4*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - c_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dV - (4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dy - 2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_y)/dV + (4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dx)*d(c_x)/dU - 4*(8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*d^2(c_x)/dUdV + 2*(2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - c_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - (4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_y)/dU + 4*(2*b_x(U, V, x, y)*c_y(U, V, x, y)^2 - b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(c_x)/dU)*d(c_x)/dV - 2*(2*(2*b_x(U, V, x, y)*c_y(U, V, x, y)^2 - b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(b_x)/dU - (2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU)*d(c_x)/dx - 2*((4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - (4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU)*d(c_x)/dy + 2*((2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - 2*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(b_y)/dU)*d(c_y)/dx + (2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dV - (4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dy - 4*(4*c_x(U, V, x, y)^2*c_y(U, V, x, y) - c_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dV + (4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dx - 2*(2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dV + 4*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(c_y)/dV)*d(d)/dU - 2*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(d)/dUdV - ((4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dU - 2*(4*c_x(U, V, x, y)^2*c_y(U, V, x, y) - c_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU - 2*(4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) + b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dU - (4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) + b_x(U, V, x, y)*d(U, V, x, y)^2)*d(d)/dU)*d(d)/dV + 2*((2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - 2*(2*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) ...
# Riem(g)^U_UVy = -1/8*(2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - c_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU*d(b_x)/dy - (4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dy*d(b_y)/dU + 2*(8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*d^2(b_x)/dUdy + 2*(16*c_x(U, V, x, y)^2*c_y(U, V, x, y)^2 - 8*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + d(U, V, x, y)^4)*d^2(b_y)/dUdV + 2*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(b_y)/dUdy - (2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - c_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - (4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_y)/dU)*d(b_y)/dx - 2*(2*(2*b_x(U, V, x, y)*c_y(U, V, x, y)^2 - b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(b_x)/dU - (2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU)*d(c_x)/dy + 2*(2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dV - (4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dy - 4*(4*c_x(U, V, x, y)^2*c_y(U, V, x, y) - c_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dV + (4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dx - 2*(2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dV)*d(c_y)/dU - 4*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(c_y)/dUdV - 2*((4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dU - 2*(4*c_x(U, V, x, y)^2*c_y(U, V, x, y) - c_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU - 4*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(c_y)/dU)*d(c_y)/dV + 2*((4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - (4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU)*d(c_y)/dx + 2*((2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - 2*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(b_y)/dU)*d(c_y)/dy - (4*(4*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - c_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dV - (4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dy - 2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_y)/dV + (4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dx - 4*(2*b_x(U, V, x, y)*c_y(U, V, x, y)^2 - b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(c_x)/dV + 2*(2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(c_y)/dV)*d(d)/dU - 2*(8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*d^2(d)/dUdV + (2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - c_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - (4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_y)/dU + 2*(4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) + b_x(U, V, x, y)*d(U, V, x, y)^2)*d(c_y)/dU + (4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) + b_y(U, V, x, y)*d(U, V, x, y)^2)*d(d)/dU)*d(d)/dV - 2*(2*(2*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(b_x)/dU - (2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x ...
# Riem(g)^U_UxU = 1/8*(8*(2*b_x(U, V, x, y)*c_y(U, V, x, y)^2 - b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*(d(c_x)/dU)^2 - 4*(2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dU*d(c_y)/dU + (4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) + b_x(U, V, x, y)*d(U, V, x, y)^2)*(d(d)/dU)^2 + 2*(16*c_x(U, V, x, y)^2*c_y(U, V, x, y)^2 - 8*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + d(U, V, x, y)^4)*d^2(b_x)/dU^2 - 2*(2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - c_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - (4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_y)/dU)*d(c_x)/dU - 4*(8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*d^2(c_x)/dU^2 + ((4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dU - 2*(4*c_x(U, V, x, y)^2*c_y(U, V, x, y) - c_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU + 4*(2*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 3*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) + b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dU + 4*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(c_y)/dU)*d(d)/dU - 2*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(d)/dU^2)/(16*c_x(U, V, x, y)^2*c_y(U, V, x, y)^2 - 8*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + d(U, V, x, y)^4)
# Riem(g)^U_UxV = 1/8*((4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dU*d(b_x)/dy - 2*(4*c_x(U, V, x, y)^2*c_y(U, V, x, y) - c_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dy*d(b_y)/dU - 4*(2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dU*d(c_y)/dV + 2*(16*c_x(U, V, x, y)^2*c_y(U, V, x, y)^2 - 8*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + d(U, V, x, y)^4)*d^2(b_x)/dUdV + 2*(8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*d^2(b_x)/dUdx + 2*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(b_y)/dUdx - ((4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dU - 2*(4*c_x(U, V, x, y)^2*c_y(U, V, x, y) - c_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU)*d(b_y)/dx - 2*(4*(4*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - c_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dV - (4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dy - 2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_y)/dV + (4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dx)*d(c_x)/dU - 4*(8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*d^2(c_x)/dUdV + 2*(2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - c_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - (4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_y)/dU + 4*(2*b_x(U, V, x, y)*c_y(U, V, x, y)^2 - b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(c_x)/dU)*d(c_x)/dV - 2*(2*(2*b_x(U, V, x, y)*c_y(U, V, x, y)^2 - b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(b_x)/dU - (2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU)*d(c_x)/dx - 2*((4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - (4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU)*d(c_x)/dy + 2*((2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - 2*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(b_y)/dU)*d(c_y)/dx + (2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dV - (4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dy - 4*(4*c_x(U, V, x, y)^2*c_y(U, V, x, y) - c_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dV + (4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dx - 2*(2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dV + 4*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(c_y)/dV)*d(d)/dU - 2*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(d)/dUdV - ((4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dU - 2*(4*c_x(U, V, x, y)^2*c_y(U, V, x, y) - c_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU - 2*(4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) + b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dU - (4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) + b_x(U, V, x, y)*d(U, V, x, y)^2)*d(d)/dU)*d(d)/dV + 2*((2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - 2*(2*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)  ...
# Riem(g)^U_Uxy = 1/4*(4*(2*b_x(U, V, x, y)*c_y(U, V, x, y)^2 - b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(c_x)/dU*d(c_x)/dy + 2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(c_x)/dU*d(c_y)/dV - 2*(2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dU*d(c_y)/dy + (16*c_x(U, V, x, y)^2*c_y(U, V, x, y)^2 - 8*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + d(U, V, x, y)^4)*d^2(b_x)/dUdy - (16*c_x(U, V, x, y)^2*c_y(U, V, x, y)^2 - 8*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + d(U, V, x, y)^4)*d^2(b_y)/dUdx - 2*((4*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - c_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dy - (4*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - c_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dx)*d(c_x)/dU - 2*(8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*d^2(c_x)/dUdy - 2*((4*c_x(U, V, x, y)^2*c_y(U, V, x, y) - c_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dy - (4*c_x(U, V, x, y)^2*c_y(U, V, x, y) - c_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dx + (4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(c_x)/dV - (2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dx - (4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dy)*d(c_y)/dU + 2*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(c_y)/dUdx - 2*((4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dU + 2*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(c_y)/dU)*d(c_y)/dx + ((4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dy - (4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_y)/dx + 2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - c_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dV - 2*(2*b_x(U, V, x, y)*c_y(U, V, x, y)^2 - b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(c_x)/dx - 2*(2*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) + b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dy - 2*(4*c_x(U, V, x, y)^2*c_y(U, V, x, y) - c_x(U, V, x, y)*d(U, V, x, y)^2)*d(c_y)/dV + 2*(2*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) + b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(c_y)/dx + 2*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(c_y)/dy)*d(d)/dU + (8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*d^2(d)/dUdx - (8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(d)/dUdy - 2*((4*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - c_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dU - (4*c_x(U, V, x, y)^2*c_y(U, V, x, y) - c_x(U, V, x, y)*d(U, V, x, y)^2)*d(c_y)/dU)*d(d)/dV - (4*(2*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(c_y)/dU - (2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(d)/dU)*d(d)/dx + (4*(2*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(c_x)/dU - (2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(d)/dU)*d(d)/dy)/(16*c_x(U, V, x, y)^2*c_y(U, V, x, y)^2 - 8*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + d(U, V, x, y)^4)
# Riem(g)^U_UyU = 1/8*(8*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*(d(c_y)/dU)^2 + (4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) + b_y(U, V, x, y)*d(U, V, x, y)^2)*(d(d)/dU)^2 + 2*(16*c_x(U, V, x, y)^2*c_y(U, V, x, y)^2 - 8*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + d(U, V, x, y)^4)*d^2(b_y)/dU^2 + 2*((4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dU - 2*(4*c_x(U, V, x, y)^2*c_y(U, V, x, y) - c_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU - 2*(2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dU)*d(c_y)/dU - 4*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(c_y)/dU^2 - (2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - c_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - (4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_y)/dU - 4*(2*b_x(U, V, x, y)*c_y(U, V, x, y)^2 - b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(c_x)/dU - 4*(2*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 3*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) + b_x(U, V, x, y)*d(U, V, x, y)^2)*d(c_y)/dU)*d(d)/dU - 2*(8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*d^2(d)/dU^2)/(16*c_x(U, V, x, y)^2*c_y(U, V, x, y)^2 - 8*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + d(U, V, x, y)^4)
# Riem(g)^U_UyV = 1/8*(2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - c_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU*d(b_x)/dy - (4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dy*d(b_y)/dU + 2*(8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*d^2(b_x)/dUdy + 2*(16*c_x(U, V, x, y)^2*c_y(U, V, x, y)^2 - 8*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + d(U, V, x, y)^4)*d^2(b_y)/dUdV + 2*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(b_y)/dUdy - (2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - c_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - (4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_y)/dU)*d(b_y)/dx - 2*(2*(2*b_x(U, V, x, y)*c_y(U, V, x, y)^2 - b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(b_x)/dU - (2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU)*d(c_x)/dy + 2*(2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dV - (4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dy - 4*(4*c_x(U, V, x, y)^2*c_y(U, V, x, y) - c_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dV + (4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dx - 2*(2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dV)*d(c_y)/dU - 4*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(c_y)/dUdV - 2*((4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dU - 2*(4*c_x(U, V, x, y)^2*c_y(U, V, x, y) - c_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU - 4*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(c_y)/dU)*d(c_y)/dV + 2*((4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - (4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU)*d(c_y)/dx + 2*((2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - 2*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(b_y)/dU)*d(c_y)/dy - (4*(4*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - c_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dV - (4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dy - 2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_y)/dV + (4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dx - 4*(2*b_x(U, V, x, y)*c_y(U, V, x, y)^2 - b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(c_x)/dV + 2*(2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(c_y)/dV)*d(d)/dU - 2*(8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*d^2(d)/dUdV + (2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - c_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - (4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_y)/dU + 2*(4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) + b_x(U, V, x, y)*d(U, V, x, y)^2)*d(c_y)/dU + (4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) + b_y(U, V, x, y)*d(U, V, x, y)^2)*d(d)/dU)*d(d)/dV - 2*(2*(2*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(b_x)/dU - (2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, ...
# Riem(g)^U_Uyx = -1/4*(4*(2*b_x(U, V, x, y)*c_y(U, V, x, y)^2 - b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(c_x)/dU*d(c_x)/dy + 2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(c_x)/dU*d(c_y)/dV - 2*(2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dU*d(c_y)/dy + (16*c_x(U, V, x, y)^2*c_y(U, V, x, y)^2 - 8*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + d(U, V, x, y)^4)*d^2(b_x)/dUdy - (16*c_x(U, V, x, y)^2*c_y(U, V, x, y)^2 - 8*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + d(U, V, x, y)^4)*d^2(b_y)/dUdx - 2*((4*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - c_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dy - (4*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - c_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dx)*d(c_x)/dU - 2*(8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*d^2(c_x)/dUdy - 2*((4*c_x(U, V, x, y)^2*c_y(U, V, x, y) - c_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dy - (4*c_x(U, V, x, y)^2*c_y(U, V, x, y) - c_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dx + (4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(c_x)/dV - (2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dx - (4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dy)*d(c_y)/dU + 2*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(c_y)/dUdx - 2*((4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dU + 2*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(c_y)/dU)*d(c_y)/dx + ((4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dy - (4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_y)/dx + 2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - c_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dV - 2*(2*b_x(U, V, x, y)*c_y(U, V, x, y)^2 - b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(c_x)/dx - 2*(2*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) + b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dy - 2*(4*c_x(U, V, x, y)^2*c_y(U, V, x, y) - c_x(U, V, x, y)*d(U, V, x, y)^2)*d(c_y)/dV + 2*(2*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) + b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(c_y)/dx + 2*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(c_y)/dy)*d(d)/dU + (8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*d^2(d)/dUdx - (8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(d)/dUdy - 2*((4*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - c_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dU - (4*c_x(U, V, x, y)^2*c_y(U, V, x, y) - c_x(U, V, x, y)*d(U, V, x, y)^2)*d(c_y)/dU)*d(d)/dV - (4*(2*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(c_y)/dU - (2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(d)/dU)*d(d)/dx + (4*(2*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(c_x)/dU - (2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(d)/dU)*d(d)/dy)/(16*c_x(U, V, x, y)^2*c_y(U, V, x, y)^2 - 8*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + d(U, V, x, y)^4)
# Riem(g)^U_VUV = 1/16*((4*b_y(U, V, x, y)^2*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)^2*d(U, V, x, y)^2)*(d(b_x)/dU)^2 + 2*(4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU*d(b_x)/dy + (4*b_x(U, V, x, y)^2*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)^2*d(U, V, x, y)^2)*(d(b_y)/dU)^2 + 4*(8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*d^2(b_x)/dUdV - 2*((4*b_x(U, V, x, y)*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU + (4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dy)*d(b_y)/dU + 4*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(b_y)/dUdV - 2*((4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - (4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU)*d(b_y)/dx - 8*(2*(2*b_x(U, V, x, y)*c_y(U, V, x, y)^2 - b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(b_x)/dV - (2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dV)*d(c_x)/dU + 4*(2*(2*b_x(U, V, x, y)*c_y(U, V, x, y)^2 - b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(b_x)/dU - (2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU)*d(c_x)/dV + 8*((2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dV - 2*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(b_y)/dV)*d(c_y)/dU - 4*((2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - 2*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(b_y)/dU)*d(c_y)/dV - 4*((4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) + b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dV + (4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) + b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dV)*d(d)/dU + 2*((4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) + b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU + (4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) + b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU)*d(d)/dV)/(16*c_x(U, V, x, y)^2*c_y(U, V, x, y)^2 - 8*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + d(U, V, x, y)^4)
# Riem(g)^U_VUx = -1/16*((8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*(d(b_x)/dU)^2 + (8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d(b_x)/dU*d(b_y)/dU + 16*(2*b_x(U, V, x, y)*c_y(U, V, x, y)^2 - b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(c_x)/dU*d(c_x)/dV + 4*(4*b_y(U, V, x, y)^2*c_x(U, V, x, y)^2*c_y(U, V, x, y) + 4*b_x(U, V, x, y)^2*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_x(U, V, x, y)*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) + b_x(U, V, x, y)*b_y(U, V, x, y)*d(U, V, x, y)^3 - (b_y(U, V, x, y)^2*c_x(U, V, x, y) + b_x(U, V, x, y)^2*c_y(U, V, x, y))*d(U, V, x, y)^2)*d^2(b_x)/dU^2 + 4*(8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*d^2(b_x)/dUdx + 4*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(b_x)/dUdy - 2*(4*(b_y(U, V, x, y)^2*c_x(U, V, x, y)*c_y(U, V, x, y) + b_x(U, V, x, y)^2*c_y(U, V, x, y)^2 - b_x(U, V, x, y)*b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(b_x)/dU - 2*(2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dy - (4*b_x(U, V, x, y)*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU + 2*(2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dx)*d(c_x)/dU - 8*(8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*d^2(c_x)/dUdV - 4*(2*(2*b_x(U, V, x, y)*c_y(U, V, x, y)^2 - b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(b_x)/dU - (2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU)*d(c_x)/dx - 4*((4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - (4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU)*d(c_x)/dy - 2*((4*b_y(U, V, x, y)^2*c_x(U, V, x, y)^2 - 4*b_x(U, V, x, y)*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) + b_x(U, V, x, y)^2*d(U, V, x, y)^2)*d(b_x)/dU + 4*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(b_x)/dy - 4*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(b_y)/dx + 4*(2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dV)*d(c_y)/dU + 4*((2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - 2*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(b_y)/dU)*d(c_y)/dx - ((4*b_x(U, V, x, y)*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) + 3*b_x(U, V, x, y)*b_y(U, V, x, y)*d(U, V, x, y)^2 - 4*(b_y(U, V, x, y)^2*c_x(U, V, x, y) + b_x(U, V, x, y)^2*c_y(U, V, x, y))*d(U, V, x, y))*d(b_x)/dU + 2*(4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) + b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dy + (4*b_x(U, V, x, y)^2*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)^2*d(U, V, x, y)^2)*d(b_y)/dU - 2*(4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) + b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dx - 4*(4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) + b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dV)*d(d)/dU - 4*(8 ...
# Riem(g)^U_VUy = -1/16*((8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*d(b_x)/dU*d(b_y)/dU + (8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d(b_y)/dU^2 + 4*(4*b_y(U, V, x, y)^2*c_x(U, V, x, y)^2*c_y(U, V, x, y) + 4*b_x(U, V, x, y)^2*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_x(U, V, x, y)*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) + b_x(U, V, x, y)*b_y(U, V, x, y)*d(U, V, x, y)^3 - (b_y(U, V, x, y)^2*c_x(U, V, x, y) + b_x(U, V, x, y)^2*c_y(U, V, x, y))*d(U, V, x, y)^2)*d^2(b_y)/dU^2 + 4*(8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*d^2(b_y)/dUdx + 4*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(b_y)/dUdy + 2*(4*(2*b_x(U, V, x, y)*c_y(U, V, x, y)^2 - b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(b_x)/dy - (4*b_x(U, V, x, y)^2*c_y(U, V, x, y)^2 - 4*b_x(U, V, x, y)*b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) + b_y(U, V, x, y)^2*d(U, V, x, y)^2)*d(b_y)/dU - 4*(2*b_x(U, V, x, y)*c_y(U, V, x, y)^2 - b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(b_y)/dx)*d(c_x)/dU - 4*(2*(2*b_x(U, V, x, y)*c_y(U, V, x, y)^2 - b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(b_x)/dU - (2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU)*d(c_x)/dy + 2*((4*b_x(U, V, x, y)*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - 2*(2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dy - 4*(b_y(U, V, x, y)^2*c_x(U, V, x, y)^2 + b_x(U, V, x, y)^2*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(b_y)/dU + 2*(2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dx)*d(c_y)/dU - 8*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(c_y)/dUdV - 8*((2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dU - 2*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(c_y)/dU)*d(c_y)/dV + 4*((4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - (4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU)*d(c_y)/dx + 4*((2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - 2*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(b_y)/dU)*d(c_y)/dy - ((4*b_y(U, V, x, y)^2*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)^2*d(U, V, x, y)^2)*d(b_x)/dU - 2*(4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) + b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dy + (4*b_x(U, V, x, y)*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) + 3*b_x(U, V, x, y)*b_y(U, V, x, y)*d(U, V, x, y)^2 - 4*(b_y(U, V, x, y)^2*c_x(U, V, x, y) + b_x(U, V, x, y)^2*c_y(U, V, x, y))*d(U, V, x, y))*d(b_y)/dU + 2*(4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) + b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dx - 4*(4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) + b_x(U, V, x, y)*d(U, V, x, y)^2)*d(c_y)/dV)*d(d)/dU - 4*(8* ...
# Riem(g)^U_VVU = -1/16*((4*b_y(U, V, x, y)^2*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)^2*d(U, V, x, y)^2)*(d(b_x)/dU)^2 + 2*(4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU*d(b_x)/dy + (4*b_x(U, V, x, y)^2*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)^2*d(U, V, x, y)^2)*(d(b_y)/dU)^2 + 4*(8*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)^2 - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + b_y(U, V, x, y)*d(U, V, x, y)^3)*d^2(b_x)/dUdV - 2*((4*b_x(U, V, x, y)*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU + (4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dy)*d(b_y)/dU + 4*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(b_y)/dUdV - 2*((4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - (4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU)*d(b_y)/dx - 8*(2*(2*b_x(U, V, x, y)*c_y(U, V, x, y)^2 - b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(b_x)/dV - (2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dV)*d(c_x)/dU + 4*(2*(2*b_x(U, V, x, y)*c_y(U, V, x, y)^2 - b_y(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y))*d(b_x)/dU - (2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU)*d(c_x)/dV + 8*((2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dV - 2*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(b_y)/dV)*d(c_y)/dU - 4*((2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - 2*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(b_y)/dU)*d(c_y)/dV - 4*((4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) + b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dV + (4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) + b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dV)*d(d)/dU + 2*((4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) + b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU + (4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - 4*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) + b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU)*d(d)/dV)/(16*c_x(U, V, x, y)^2*c_y(U, V, x, y)^2 - 8*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + d(U, V, x, y)^4)
# ...
# Riem(g)^y_yxV = -1/16*(2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dU*d(b_x)/dy + 2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dU*d(b_y)/dx + 4*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_y)/dU*d(c_x)/dV + 8*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d^2(b_x)/dxdy + ((8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d(b_x)/dU - 4*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dx)*d(b_y)/dU + 4*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(b_y)/dUdx - 8*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d^2(b_y)/dx^2 + 2*(2*(4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dy - (4*b_x(U, V, x, y)*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU - 2*(4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dx)*d(c_x)/dU - 16*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d^2(c_x)/dVdy - 4*(4*c_y(U, V, x, y)*d(U, V, x, y)*d(b_x)/dy - 4*c_y(U, V, x, y)*d(U, V, x, y)*d(b_y)/dx - (2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU)*d(c_x)/dx + 4*(8*c_y(U, V, x, y)*d(U, V, x, y)*d(c_x)/dV - (4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU)*d(c_x)/dy + 16*(d(U, V, x, y)^2*d(c_x)/dx + 2*c_x(U, V, x, y)*d(U, V, x, y)*d(c_x)/dy)*d(c_y)/dV - 8*(2*c_x(U, V, x, y)*d(U, V, x, y)*d(b_x)/dy - 2*c_x(U, V, x, y)*d(U, V, x, y)*d(b_y)/dx + 2*d(U, V, x, y)^2*d(c_x)/dV + (2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(b_y)/dU)*d(c_y)/dx + ((4*b_x(U, V, x, y)*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - 4*(2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dV + 8*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(c_y)/dV)*d(d)/dU - 4*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(d)/dUdV - 2*(8*c_y(U, V, x, y)*d(U, V, x, y)*d(c_x)/dx + 8*d(U, V, x, y)^2*d(c_x)/dy - 8*c_x(U, V, x, y)*d(U, V, x, y)*d(c_y)/dx + (4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dU - 2*(4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dU + 2*(2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(d)/dU)*d(d)/dV + 8*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d^2(d)/dVdx + 4*(2*d(U, V, x, y)^2*d(b_x)/dy - 2*d(U, V, x, y)^2*d(b_y)/dx - 8*c_x(U, V, x, y)*d(U, V, x, y)*d(c_y)/dV + 2*d(U, V, x, y)^2*d(d)/dV + (2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU)*d(d)/dx)/(16*c_x(U, V, x, y)^2*c_y(U, V, x, y)^2 - 8*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + d(U, V, x, y)^4)
# Riem(g)^y_yxy = -1/16*(32*c_y(U, V, x, y)*d(U, V, x, y)*(d(c_x)/dy)^2 + 32*c_x(U, V, x, y)*d(U, V, x, y)*(d(c_y)/dx)^2 - 8*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_y)/dy*d(c_x)/dU + 8*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(c_x)/dU*d(c_y)/dV + (4*b_x(U, V, x, y)*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*b_y(U, V, x, y)*d(U, V, x, y)^2)*(d(d)/dU)^2 - 4*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(d)/dU*d(d)/dV - 16*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d^2(c_x)/dy^2 + 2*((8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d(b_x)/dU - 4*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dx - 2*(4*b_x(U, V, x, y)*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dU + 4*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(c_x)/dV + 4*(2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dx)*d(c_y)/dU + 8*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(c_y)/dUdx + 8*(4*c_y(U, V, x, y)*d(U, V, x, y)*d(c_x)/dx - 2*d(U, V, x, y)^2*d(c_x)/dy - (4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dU - 2*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(c_y)/dU)*d(c_y)/dx - 16*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d^2(c_y)/dx^2 + 16*(d(U, V, x, y)^2*d(c_x)/dx + 2*c_x(U, V, x, y)*d(U, V, x, y)*d(c_x)/dy)*d(c_y)/dy + (4*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dy - (8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d(b_y)/dU + 4*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_y)/dx - 8*(2*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) + b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dy + 8*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(c_y)/dy)*d(d)/dU - 4*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(d)/dUdy - 8*(2*d(U, V, x, y)^2*d(c_y)/dx + 4*c_x(U, V, x, y)*d(U, V, x, y)*d(c_y)/dy - (2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(c_y)/dU)*d(d)/dx + 16*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d^2(d)/dxdy - 4*(8*c_y(U, V, x, y)*d(U, V, x, y)*d(c_x)/dx + 4*d(U, V, x, y)^2*d(c_x)/dy - 4*d(U, V, x, y)^2*d(d)/dx - 2*(4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dU + (2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(d)/dU)*d(d)/dy)/(16*c_x(U, V, x, y)^2*c_y(U, V, x, y)^2 - 8*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + d(U, V, x, y)^4)
# Riem(g)^y_yyU = 1/8*(8*d(U, V, x, y)^2*d(c_x)/dU*d(c_y)/dy - 8*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*(d(c_y)/dU)^2 - (4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*(d(d)/dU)^2 - 2*(4*d(U, V, x, y)^2*d(c_x)/dy + (4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dU - 2*(2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dU)*d(c_y)/dU + 4*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(c_y)/dU^2 - 8*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d^2(c_y)/dUdx + 16*(c_y(U, V, x, y)*d(U, V, x, y)*d(c_x)/dU + c_x(U, V, x, y)*d(U, V, x, y)*d(c_y)/dU)*d(c_y)/dx + (8*c_y(U, V, x, y)*d(U, V, x, y)*d(c_x)/dy - 8*d(U, V, x, y)^2*d(c_y)/dx - 8*c_x(U, V, x, y)*d(U, V, x, y)*d(c_y)/dy + (4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_y)/dU + 4*(2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(c_y)/dU)*d(d)/dU + 4*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d^2(d)/dUdy - 4*(4*c_y(U, V, x, y)*d(U, V, x, y)*d(c_x)/dU - d(U, V, x, y)^2*d(d)/dU)*d(d)/dy)/(16*c_x(U, V, x, y)^2*c_y(U, V, x, y)^2 - 8*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + d(U, V, x, y)^4)
# Riem(g)^y_yyV = 1/16*(2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dy*d(b_y)/dU - (8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d(b_y)/dU^2 + 2*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_y)/dU*d(b_y)/dx - 4*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dU*d(b_y)/dy - 8*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d^2(b_x)/dy^2 - 4*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(b_y)/dUdy + 8*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d^2(b_y)/dxdy + 4*(4*c_y(U, V, x, y)*d(U, V, x, y)*d(b_x)/dy - 4*c_y(U, V, x, y)*d(U, V, x, y)*d(b_y)/dx - (2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU)*d(c_x)/dy - 2*((4*b_x(U, V, x, y)*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU - 4*(2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dV)*d(c_y)/dU + 8*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(c_y)/dUdV - 4*(4*d(U, V, x, y)^2*d(c_x)/dy - (4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dU + 4*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(c_y)/dU)*d(c_y)/dV - 16*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d^2(c_y)/dVdx + 4*(8*c_y(U, V, x, y)*d(U, V, x, y)*d(c_x)/dV + 8*c_x(U, V, x, y)*d(U, V, x, y)*d(c_y)/dV - (4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU)*d(c_y)/dx + 8*(2*c_x(U, V, x, y)*d(U, V, x, y)*d(b_x)/dy - 2*c_x(U, V, x, y)*d(U, V, x, y)*d(b_y)/dx + 2*d(U, V, x, y)^2*d(c_x)/dV + (2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(b_y)/dU)*d(c_y)/dy - (2*(4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dy - (4*b_x(U, V, x, y)*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU - 2*(4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dx)*d(d)/dU + 2*(8*c_y(U, V, x, y)*d(U, V, x, y)*d(c_x)/dy - 8*d(U, V, x, y)^2*d(c_y)/dx - 8*c_x(U, V, x, y)*d(U, V, x, y)*d(c_y)/dy - (4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_y)/dU + 4*(2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(c_y)/dU - (4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(d)/dU)*d(d)/dV + 8*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d^2(d)/dVdy - 4*(2*d(U, V, x, y)^2*d(b_x)/dy - 2*d(U, V, x, y)^2*d(b_y)/dx + 8*c_y(U, V, x, y)*d(U, V, x, y)*d(c_x)/dV - 2*d(U, V, x, y)^2*d(d)/dV - (4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(b_x)/dU + (2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(b_y)/dU)*d(d)/dy)/(16*c_x(U, V, x, y)^2*c_y(U, V, x, y)^2 - 8*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + d(U, V, x, y)^4)
# Riem(g)^y_yyx = 1/16*(32*c_y(U, V, x, y)*d(U, V, x, y)*(d(c_x)/dy)^2 + 32*c_x(U, V, x, y)*d(U, V, x, y)*(d(c_y)/dx)^2 - 8*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_y)/dy*d(c_x)/dU + 8*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(c_x)/dU*d(c_y)/dV + (4*b_x(U, V, x, y)*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*b_y(U, V, x, y)*d(U, V, x, y)^2)*(d(d)/dU)^2 - 4*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(d)/dU*d(d)/dV - 16*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d^2(c_x)/dy^2 + 2*((8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d(b_x)/dU - 4*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dx - 2*(4*b_x(U, V, x, y)*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_x(U, V, x, y)*b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dU + 4*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(c_x)/dV + 4*(2*b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dx)*d(c_y)/dU + 8*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(c_y)/dUdx + 8*(4*c_y(U, V, x, y)*d(U, V, x, y)*d(c_x)/dx - 2*d(U, V, x, y)^2*d(c_x)/dy - (4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dU - 2*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(c_y)/dU)*d(c_y)/dx - 16*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d^2(c_y)/dx^2 + 16*(d(U, V, x, y)^2*d(c_x)/dx + 2*c_x(U, V, x, y)*d(U, V, x, y)*d(c_x)/dy)*d(c_y)/dy + (4*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_x)/dy - (8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d(b_y)/dU + 4*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d(b_y)/dx - 8*(2*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) + b_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dy + 8*(2*b_y(U, V, x, y)*c_x(U, V, x, y)^2 - b_x(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y))*d(c_y)/dy)*d(d)/dU - 4*(8*b_y(U, V, x, y)*c_x(U, V, x, y)^2*c_y(U, V, x, y) - 4*b_x(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - 2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y)^2 + b_x(U, V, x, y)*d(U, V, x, y)^3)*d^2(d)/dUdy - 8*(2*d(U, V, x, y)^2*d(c_y)/dx + 4*c_x(U, V, x, y)*d(U, V, x, y)*d(c_y)/dy - (2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(c_y)/dU)*d(d)/dx + 16*(4*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y) - d(U, V, x, y)^3)*d^2(d)/dxdy - 4*(8*c_y(U, V, x, y)*d(U, V, x, y)*d(c_x)/dx + 4*d(U, V, x, y)^2*d(c_x)/dy - 4*d(U, V, x, y)^2*d(d)/dx - 2*(4*b_y(U, V, x, y)*c_x(U, V, x, y)*c_y(U, V, x, y) - b_y(U, V, x, y)*d(U, V, x, y)^2)*d(c_x)/dU + (2*b_y(U, V, x, y)*c_x(U, V, x, y)*d(U, V, x, y) - b_x(U, V, x, y)*d(U, V, x, y)^2)*d(d)/dU)*d(d)/dy)/(16*c_x(U, V, x, y)^2*c_y(U, V, x, y)^2 - 8*c_x(U, V, x, y)*c_y(U, V, x, y)*d(U, V, x, y)^2 + d(U, V, x, y)^4)
